# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Read 2007-2017

# %%
df={}
columns = ['FIPS Code', 'MSA Description', 'NAICS Code', 'NAICS Description',
       'Enterprise Employment Size', 'Number of Firms',
       'Number of Establishments', 'Employment', 'Annual Payroll ($1,000)']

# %%
# 2017
df_ = pd.read_excel('data/susb/msa_naicssector_2017.xlsx',skiprows=5,usecols=[0,1,2,3,4,5,6,7,10])
df_ = df_.drop([0,1])
df_.columns = columns
df_['FIPS Code'] = df_['FIPS Code'].astype('int64')
df[2017] = df_.where( df_['Enterprise Employment Size']=='01:  Total' ).dropna()

# %%
# 2016
df_ = pd.read_excel('data/susb/msa_naicssector_2016.xlsx',skiprows=5,usecols=[0,1,2,3,4,5,6,7,10])
df_ = df_.drop([0,1])
df_.columns = columns
df_ = df_[ ~pd.isna( df_['FIPS Code'] ) ]
df_['FIPS Code'] = df_['FIPS Code'].astype('int64')
df[2016] = df_.where( df_['Enterprise Employment Size']=='01:  Total' ).dropna()

# %%
# 2015
df_ = pd.read_excel('data/susb/msa_naicssector_2015.xlsx',skiprows=4,usecols=[0,1,2,3,4,5,6,7,10])
df_ = df_.drop([0,1])
df_.columns = columns
df_ = df_[ ~pd.isna( df_['FIPS Code'] ) ]
df_['FIPS Code'] = df_['FIPS Code'].astype('int64')
df[2015] = df_.where( df_['Enterprise Employment Size']=='01:  Total' ).dropna()

# %%
# 2014
df_ = pd.read_excel('data/susb/msa_naicssector_2014.xlsx',skiprows=4,usecols=[0,1,2,3,4,5,6,7,10])
df_ = df_.drop([0,1])
df_.columns = columns
df_ = df_[ ~pd.isna( df_['FIPS Code'] ) ]
df_['FIPS Code'] = df_['FIPS Code'].astype('int64')
df[2014] = df_.where( df_['Enterprise Employment Size']=='01:  Total' ).dropna()

# %%
# 2013
df_ = pd.read_excel('data/susb/msa_naicssector_2013.xlsx',skiprows=4,usecols=[0,1,2,3,4,5,6,7,10])
df_ = df_.drop([0,1])
df_.columns = columns
df_ = df_[ ~pd.isna( df_['FIPS Code'] ) ]
df_['FIPS Code'] = df_['FIPS Code'].astype('int64')
df[2013] = df_.where( df_['Enterprise Employment Size']=='01:  Total' ).dropna()

# %%
# 2012
df_ = pd.read_excel('data/susb/msa_naicssector_2012.xlsx',skiprows=5,usecols=[0,1,2,3,4,5,6,7,10])
df_ = df_.drop([0,1])
df_.columns = columns
df_ = df_[ ~pd.isna( df_['FIPS Code'] ) ]
df_['FIPS Code'] = df_['FIPS Code'].astype('int64')
df[2012] = df_.where( df_['Enterprise Employment Size']==df_['Enterprise Employment Size'].iloc[0] ).dropna()

# %%
# 2011 1
df_ = pd.read_excel('data/susb/msa_glensfallsny-owensboroky_naicssector_2011.xls',skiprows=5,usecols=[0,1,2,3,4,5,6,7,10])
df_ = df_.drop([0,1])
df_.columns = columns
df_ = df_[ ~pd.isna( df_['FIPS Code'] ) ]
df_['FIPS Code'] = df_['FIPS Code'].astype('int64')
df_1 = df_.where( df_['Enterprise Employment Size']==df_['Enterprise Employment Size'].iloc[0] ).dropna()

# %%
# 2011 2
df_ = pd.read_excel('data/susb/msa_owossomi-zanesvilleoh_naicssector_2011.xls',skiprows=5,usecols=[0,1,2,3,4,5,6,7,10])
df_ = df_.drop([0,1])
df_.columns = columns
df_ = df_[ ~pd.isna( df_['FIPS Code'] ) ]
df_['FIPS Code'] = df_['FIPS Code'].astype('int64')
df_2 = df_.where( df_['Enterprise Employment Size']==df_['Enterprise Employment Size'].iloc[0] ).dropna()

# %%
# 2011 3
df_ = pd.read_excel('data/susb/msa_abbevillela-glasgowky_naicssector_2011.xls',skiprows=5,usecols=[0,1,2,3,4,5,6,7,10])
df_ = df_.drop([0,1])
df_.columns = columns
df_ = df_[ ~pd.isna( df_['FIPS Code'] ) ]
df_['FIPS Code'] = df_['FIPS Code'].astype('int64')
df_3 = df_.where( df_['Enterprise Employment Size']==df_['Enterprise Employment Size'].iloc[0] ).dropna()

# %%
# 2011
df[2011] = pd.concat([df_3,df_1,df_2])

# %%
# 2010
df_ = pd.read_excel('data/susb/msa_naicssector_2010.xlsx',skiprows=5,usecols=[0,1,2,3,4,5,6,7,10])
df_ = df_.drop([0,1])
df_.columns = columns
df_ = df_[ ~pd.isna( df_['FIPS Code'] ) ]
df_['FIPS Code'] = df_['FIPS Code'].astype('int64')
df[2010] = df_.where( df_['Enterprise Employment Size']==df_['Enterprise Employment Size'].iloc[0] ).dropna()

# %%
# 2009
df_ = pd.read_excel('data/susb/msa_naicssector_2009.xlsx',skiprows=5,usecols=[0,1,2,3,4,5,6,7,10])
df_ = df_.drop([0,1])
df_.columns = columns
df_ = df_[ ~pd.isna( df_['FIPS Code'] ) ]
df_['FIPS Code'] = df_['FIPS Code'].astype('int64')
df[2009] = df_.where( df_['Enterprise Employment Size']==df_['Enterprise Employment Size'].iloc[0] ).dropna()

# %%
# 2008
df_ = pd.read_excel('data/susb/msa_abbevillela-glasgowky_naicssector_2008.xls',skiprows=5,usecols=[0,1,2,3,4,5,6,7,10])
df_ = df_.drop([0])
df_.columns = columns
df_ = df_[ ~pd.isna( df_['FIPS Code'] ) ]
df_['FIPS Code'] = df_['FIPS Code'].astype('int64')
df_1 = df_.where( df_['Enterprise Employment Size']==df_['Enterprise Employment Size'].iloc[0] ).dropna()

# %%
df_ = pd.read_excel('data/susb/msa_glensfallsny-owensboroky_naicssector_2008.xls',skiprows=5,usecols=[0,1,2,3,4,5,6,7,10])
df_ = df_.drop([0])
df_.columns = columns
df_ = df_[ ~pd.isna( df_['FIPS Code'] ) ]
df_['FIPS Code'] = df_['FIPS Code'].astype('int64')
df_2 = df_.where( df_['Enterprise Employment Size']==df_['Enterprise Employment Size'].iloc[0] ).dropna()

# %%
df_ = pd.read_excel('data/susb/msa_owossomi-zanesvilleoh_naicssector_2008.xls',skiprows=5,usecols=[0,1,2,3,4,5,6,7,10])
df_ = df_.drop([0])
df_.columns = columns
df_ = df_[ ~pd.isna( df_['FIPS Code'] ) ]
df_['FIPS Code'] = df_['FIPS Code'].astype('int64')
df_3 = df_.where( df_['Enterprise Employment Size']==df_['Enterprise Employment Size'].iloc[0] ).dropna()

# %%
df[2008] = pd.concat([df_1,df_2,df_3])

# %%
# 2007
df_ = pd.read_excel('data/susb/msa_abbevillela-glasgowky_naicssector_2007.xls',skiprows=5,usecols=[0,1,2,3,4,5,6,7,10])
df_ = df_.drop([0,1])
df_.columns = columns
df_ = df_[ ~pd.isna( df_['FIPS Code'] ) ]
df_['FIPS Code'] = df_['FIPS Code'].astype('int64')
df_1 = df_.where( df_['Enterprise Employment Size']==df_['Enterprise Employment Size'].iloc[0] ).dropna()

df_ = pd.read_excel('data/susb/msa_glensfallsny-owensboroky_naicssector_2007.xls',skiprows=5,usecols=[0,1,2,3,4,5,6,7,10])
df_ = df_.drop([0,1,2])
df_.columns = columns
df_ = df_[ ~pd.isna( df_['FIPS Code'] ) ]
df_['FIPS Code'] = df_['FIPS Code'].astype('int64')
df_2 = df_.where( df_['Enterprise Employment Size']==df_['Enterprise Employment Size'].iloc[0] ).dropna()

df_ = pd.read_excel('data/susb/msa_owossomi-zanesvilleoh_naicssector_2007.xls',skiprows=5,usecols=[0,1,2,3,4,5,6,7,10])
df_ = df_.drop([0,1])
df_.columns = columns
df_ = df_[ ~pd.isna( df_['FIPS Code'] ) ]
df_['FIPS Code'] = df_['FIPS Code'].astype('int64')
df_3 = df_.where( df_['Enterprise Employment Size']==df_['Enterprise Employment Size'].iloc[0] ).dropna()

df[2007] = pd.concat([df_1,df_2,df_3])

# %%
# Saved the processed ones
for year in range(2007,2018):
    df[year]['year'] = year
    df[year].to_csv('data/susb/msa_naicssector_cleaned_tot_'+str(year)+'.csv')

# %% [markdown]
# # Read -2007

# %%
columns_old = ['FIPS Code', 'MSA Description', 'NAICS Code', 'Total',
       'Enterprise Employment Size', 'Number of Firms',
       'Number of Establishments', 'Employment', 'Annual Payroll ($1,000)']

# %%
# 2006
df_ = pd.read_excel('data/susb/msa_abbevillela-lawrenceburgtn_naicssector_2006.xls',skiprows=8,usecols=[0:12])
df_ = df_.drop([0])
df_.columns = columns
df_ = df_[ ~pd.isna( df_['FIPS Code'] ) ]
df_['FIPS Code'] = df_['FIPS Code'].astype('int64')
df_1 = df_.where( df_['Enterprise Employment Size']==df_['Enterprise Employment Size'].iloc[0] ).dropna()

# %% [markdown]
# # Read processed

# %%
df = {}
for year in range(2007,2018):
    df[year] = pd.read_csv('data/susb/msa_naicssector_cleaned_tot_'+str(year)+'.csv')

# %%
df_la = {}
for year in range(2007,2018):
    df_la[year] = df[year][ df[year]['MSA Description'].map(lambda x: 'Los Angeles' in x )  ]
    df_la[year]['Enterprise Employment Size'] = df_la[year]['Enterprise Employment Size'].map(lambda x: int( x.split(':')[0] ))
# Out:
# <ipython-input-120-7ceffdb8853e>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_la[year]['Enterprise Employment Size'] = df_la[year]['Enterprise Employment Size'].map(lambda x: int( x.split(':')[0] ))

# %%
years = list( range(2007,2018) )
employ = {}
for year in range(2007,2018):
    total = df_la[year][ (df_la[year]['NAICS Code']=='--') & (df_la[year]['Enterprise Employment Size']==1) ]
    employ[year] = total['Employment'].iloc[0]
    #print(year,  total['Employment'] )

# %%
len(df[2007]['FIPS Code'].unique())
# Out:
# 939

# %%
plt.figure()

plt.plot( employ.keys(),employ.values() )

# %%
year = 2012
df_la[year][ (df_la[year]['NAICS Code']=='--') & (df_la[year]['Enterprise Employment Size']==1) ]
# Out:
# Empty DataFrame
# Columns: [FIPS Code, MSA Description, NAICS Code, NAICS Description, Enterprise Employment Size, Number of Firms, Number of Establishments, Employment, Annual Payroll ($1,000), year]
# Index: []

# %%
df_la[year]
# Out:
# Empty DataFrame
# Columns: [FIPS Code, MSA Description, NAICS Code, NAICS Description, Enterprise Employment Size, Number of Firms, Number of Establishments, Employment, Annual Payroll ($1,000), year]
# Index: []

# %%
df[year][ df[year]['MSA Description']==31100 ]
# Out:
# Empty DataFrame
# Columns: [FIPS Code, MSA Description, NAICS Code, NAICS Description, Enterprise Employment Size, Number of Firms, Number of Establishments, Employment, Annual Payroll ($1,000), year]
# Index: []

# %%
df[year][ df[year]['MSA Description'].map(lambda x: 'Los Angeles' in x )  ]
# Out:
#        FIPS Code                                MSA Description NAICS Code  \
# 79066    31080.0  Los Angeles-Long Beach-Anaheim, CA Metro Area         --
# 79075    31080.0  Los Angeles-Long Beach-Anaheim, CA Metro Area         11
# 79083    31080.0  Los Angeles-Long Beach-Anaheim, CA Metro Area         21
# 79092    31080.0  Los Angeles-Long Beach-Anaheim, CA Metro Area         22
# 79101    31080.0  Los Angeles-Long Beach-Anaheim, CA Metro Area         23
# 79110    31080.0  Los Angeles-Long Beach-Anaheim, CA Metro Area      31-33
# 79119    31080.0  Los Angeles-Long Beach-Anaheim, CA Metro Area         42
# 79128    31080.0  Los Angeles-Long Beach-Anaheim, CA Metro Area      44-45
# 79137    31080.0  Los Angeles-Long Beach-Anaheim, CA Metro Area      48-49
# 79146    31080.0  Los Angeles-Long Beach-Anaheim, CA Metro Area         51
# 79155    31080.0  Los Angeles-Long Beach-Anaheim, CA Metro Area         52
# 79164    31080.0  Los Angeles-Long Beach-Anaheim, CA Metro Area         53
# 79173    31080.0  Los Angeles-Long Beach-Anaheim, CA Metro Area         54
# 79182    31080.0  Los Angeles-Long Beach-Anaheim, CA Metro Area         55
# 79191    31080.0  Los Angeles-Long Beach-Anaheim, CA Metro Area         56
# 79200    31080.0  Los Angeles-Long Beach-Anaheim, CA Metro Area         61
# 79209    31080.0  Los Angeles-Long Beach-Anaheim, CA Metro Area         62
# 79218    31080.0  Los Angeles-Long Beach-Anaheim, CA Metro Area         71
# 79227    31080.0  Los Angeles-Long Beach-Anaheim, CA Metro Area         72
# 79236    31080.0  Los Angeles-Long Beach-Anaheim, CA Metro Area         81
# 79245    31080.0  Los Angeles-Long Beach-Anaheim, CA Metro Area         99
#
#                                        NAICS Description  \
# 79066                                              Total
# 79075         Agriculture, Forestry, Fishing and Hunting
# 79083      Mining, Quarrying, and Oil and Gas Extraction
# 79092                                          Utilities
# 79101                                       Construction
# 79110                                      Manufacturing
# 79119                                    Wholesale Trade
# 79128                                       Retail Trade
# 79137                     Transportation and Warehousing
# 79146                                        Information
# 79155                              Finance and Insurance
# 79164                 Real Estate and Rental and Leasing
# 79173   Professional, Scientific, and Technical Services
# 79182            Management of Companies and Enterprises
# 79191  Administrative and Support and Waste Managemen...
# 79200                               Educational Services
# 79209                  Health Care and Social Assistance
# 79218                Arts, Entertainment, and Recreation
# 79227                    Accommodation and Food Services
# 79236      Other Services (except Public Administration)
# 79245                          Industries not classified
#
#       Enterprise Employment Size  Number of Firms  Number of Establishments  \
# 79066                 1:   Total         287801.0                  338007.0
# 79075                 1:   Total            158.0                     158.0
# 79083                 1:   Total            141.0                     159.0
# 79092                 1:   Total            105.0                     316.0
# 79101                 1:   Total          18846.0                   19011.0
# 79110                 1:   Total          16908.0                   17504.0
# 79119                 1:   Total          28839.0                   30634.0
# 79128                 1:   Total          26023.0                   37699.0
# 79137                 1:   Total           6890.0                    7880.0
# 79146                 1:   Total           9076.0                   11295.0
# 79155                 1:   Total          11836.0                   19041.0
# 79164                 1:   Total          15978.0                   18999.0
# 79173                 1:   Total          43708.0                   45726.0
# 79182                 1:   Total           1349.0                    1981.0
# 79191                 1:   Total          13285.0                   15129.0
# 79200                 1:   Total           4430.0                    4853.0
# 79209                 1:   Total          36100.0                   40681.0
# 79218                 1:   Total          13239.0                   13623.0
# 79227                 1:   Total          20685.0                   27342.0
# 79236                 1:   Total          22830.0                   25582.0
# 79245                 1:   Total            394.0                     394.0
#
#        Employment  Annual Payroll ($1,000)  year
# 79066   5011004.0              258242992.0  2012
# 79075       633.0                  21684.0  2012
# 79083      2877.0                 334007.0  2012
# 79092         0.0                      0.0  2012
# 79101    180638.0                9615338.0  2012
# 79110    502890.0               27528161.0  2012
# 79119    347845.0               20746040.0  2012
# 79128    529525.0               15144588.0  2012
# 79137    181166.0                8622887.0  2012
# 79146    236316.0               20867474.0  2012
# 79155    242003.0               24070989.0  2012
# 79164    123025.0                6718596.0  2012
# 79173    449867.0               34826280.0  2012
# 79182    121711.0               11190829.0  2012
# 79191    435752.0               14490001.0  2012
# 79200    167928.0                5926657.0  2012
# 79209    636582.0               31632839.0  2012
# 79218    121539.0                8852917.0  2012
# 79227    498164.0                9347762.0  2012
# 79236    209665.0                6045694.0  2012
# 79245       397.0                  10518.0  2012

# %%
df[year]['MSA Description'].map(lambda x: 'Los Angeles' in x )
# Out:
# 2         False
# 11        False
# 16        False
# 21        False
# 26        False
#           ...
# 149024    False
# 149030    False
# 149039    False
# 149044    False
# 149052    False
# Name: MSA Description, Length: 18819, dtype: bool

# %%
df_
# Out:
#        FIPS Code                              MSA Description NAICS Code  \
# 2          10020  Abbeville, LA Micropolitan Statistical Area         --
# 3          10020  Abbeville, LA Micropolitan Statistical Area         --
# 4          10020  Abbeville, LA Micropolitan Statistical Area         --
# 5          10020  Abbeville, LA Micropolitan Statistical Area         --
# 6          10020  Abbeville, LA Micropolitan Statistical Area         --
# ...          ...                                          ...        ...
# 53982      23980    Glasgow, KY Micropolitan Statistical Area         81
# 53983      23980    Glasgow, KY Micropolitan Statistical Area         99
# 53984      23980    Glasgow, KY Micropolitan Statistical Area         99
# 53985      23980    Glasgow, KY Micropolitan Statistical Area         99
# 53986      23980    Glasgow, KY Micropolitan Statistical Area         99
#
#                                    NAICS Description  \
# 2                                              Total
# 3                                              Total
# 4                                              Total
# 5                                              Total
# 6                                              Total
# ...                                              ...
# 53982  Other services (except public administration)
# 53983                      Industries not classified
# 53984                      Industries not classified
# 53985                      Industries not classified
# 53986                      Industries not classified
#
#       Enterprise Employment Size Number of Firms Number of Establishments  \
# 2                       2:   0-4             504                      504
# 3                       3:   5-9             165                      166
# 4                     4:   10-19              95                       99
# 5                       5:   <20             764                      769
# 6                     6:   20-99              90                      107
# ...                          ...             ...                      ...
# 53982                  9:   500+               1                        1
# 53983                 1:   Total               2                        2
# 53984                   2:   0-4               2                        2
# 53985                   5:   <20               2                        2
# 53986                  8:   <500               2                        2
#
#       Employment  Annual Payroll ($1,000)
# 2            908                    29103
# 3           1079                    26293
# 4           1219                    34284
# 5           3206                    89680
# 6           2551                    74491
# ...          ...                      ...
# 53982          0                        0
# 53983          0                        0
# 53984          0                        0
# 53985          0                        0
# 53986          0                        0
#
# [53985 rows x 9 columns]
