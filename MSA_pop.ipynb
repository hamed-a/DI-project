# %%
import pandas as pd

# %%
msa = pd.read_csv('data/susb/MSA_wikipedia.csv',delimiter='\t')

# %%
msa
# Out:
#      Rank                    Metropolitan statistical area   2019 estimate   \
# 0        1  New York City-Newark-Jersey City, NY-NJ-PA MSA         19216182
# 1        2          Los Angeles-Long Beach-Anaheim, CA MSA         13214799
# 2        3          Chicago-Naperville-Elgin, IL-IN-WI MSA          9458539
# 3        4             Dallas-Fort Worth-Arlington, TX MSA          7573136
# 4        5        Houston-The Woodlands-Sugar Land, TX MSA          7066141
# ..     ...                                              ...             ...
# 379    380                            Grand Island, NE MSA            75553
# 380    381                             Lewiston, ID-WA MSA            62990
# 381    382                                    Enid, OK MSA            61056
# 382    383                             Walla Walla, WA MSA            60760
# 383    384                             Carson City, NV MSA            55916
#
# ...
